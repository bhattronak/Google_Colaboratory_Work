# %% [markdown]
# <a href="https://colab.research.google.com/github/bhattronak/Google_Colaboratory_Work/blob/main/Avg_Distance_Between_2Points_in_N_dimension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import math

# %%
def avg(lis):
  sum=0
  for i in range(len(lis)):
    sum=sum+lis[i]
  return sum/len(lis)
avg([2,3,4])
# Out:
# 3.0

# %% [markdown]
# ### Conclusion
# It's counter intuting thing.
# Average distance between 2 points from 1-D to infinite dimensions is Always increasing!
# I found this very  interesting.
# when I read it I wanted to feel it so I started my laptop & started coding.
# This code will find average distance between 2 points in 1* 1* 1*....(N dimension) hypercube(Hypercube with all adges equal to 1)

# %%
import math
def rand(iteration,dim):
  lstofrandom=[]
  d=0
  count=0
  for i in range(0,iteration):
    d=0
    for i in range(0,dim):
        n1=random.random()
        n2=random.random()
        d=d+(n1-n2)**2
    lstofrandom.append(math.sqrt(d))
  return avg(lstofrandom)
a=0
print("For ",1,"th dimension space the average distance between 2 points is",rand(100,1))
print("For ",2,"th dimension space the average distance between 2 points is",rand(100,2))
print("For ",3,"th dimension space the average distance between 2 points is",rand(100,3))
for i in range(0,1000):
  print("For ",a+10,"th dimension space the average distance between 2 points is",rand(100,a+10))
  a=a+10
# Out:
# For  1 th dimension space the average distance between 2 points is 0.2890864473227653
# For  2 th dimension space the average distance between 2 points is 0.5338284655868196
# For  3 th dimension space the average distance between 2 points is 0.6567233276284279
# For  10 th dimension space the average distance between 2 points is 1.2486164835862155
# For  20 th dimension space the average distance between 2 points is 1.8474737773968337
# For  30 th dimension space the average distance between 2 points is 2.244013044925943
# For  40 th dimension space the average distance between 2 points is 2.5810090118729216
# For  50 th dimension space the average distance between 2 points is 2.8839155249215485
# For  60 th dimension space the average distance between 2 points is 3.1976923022167476
# For  70 th dimension space the average distance between 2 points is 3.3744918999932914
# For  80 th dimension space the average distance between 2 points is 3.621958295607783
# ...

# %%
 d=0
for i in range(0,2):
        n1=random.random()
        n2=random.random()
        d=d+(n1-n2)**2
print(d)
print((n1-n2)**2)
# Out:
# 0.003091116694569701
# 0.003091116694569701

# %%
a=[1,2,3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e91d5952d8f6> in <module>
#       1 a=[1,2,3]
# ----> 2 average(a)
#
# NameError: name 'average' is not defined

# %%
a=[1,2,3]
sum(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-4e024f2db3b2> in <module>
#       1 a=[1,2,3]
# ----> 2 sum(a)
#
# TypeError: 'int' object is not callable
